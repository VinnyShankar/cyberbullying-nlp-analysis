# %%
# imports
import pandas as pd

# %%
df1 = pd.read_json("small_channels_comments.json")
df1["channel_size"] = [0]*len(df1)
df1.head()
# Out:
#       category                                   channel  \
# 0  Automobiles  https://www.youtube.com/@autofanaticcars
# 1  Automobiles  https://www.youtube.com/@autofanaticcars
# 2  Automobiles  https://www.youtube.com/@autofanaticcars
# 3  Automobiles      https://www.youtube.com/@AutoAmateur
# 4  Automobiles      https://www.youtube.com/@AutoAmateur
#
#                                      video_url     video_id  \
# 0  https://www.youtube.com/watch?v=Wqcy9do6YO0  Wqcy9do6YO0
# 1  https://www.youtube.com/watch?v=NyNF0MfQN8s  NyNF0MfQN8s
# 2  https://www.youtube.com/watch?v=x3vzurNYbyM  x3vzurNYbyM
# 3  https://www.youtube.com/watch?v=qysq4YFOwPw  qysq4YFOwPw
# 4  https://www.youtube.com/watch?v=B8zgCdINaAs  B8zgCdINaAs
#
#                                             comments  channel_size
# 0  [Wheel Cleaner is In production and pre-order ...             0
# 1  [I know that on my 1122TST it also matters wha...             0
# 2  [Can you put it on top of PPF? Thanks, very ha...             0
# 3  [Hey australian Elon Musk can you show a littl...             0
# 4  [Excellent tutorial video. Congrats! Maybe two...             0

# %%
df2 = pd.read_json("large_channels_comments.json")
df2["channel_size"] = [1]*len(df2)
df2.head()
# Out:
#       category                                   channel  \
# 0  Automobiles  https://www.youtube.com/@SupercarBlondie
# 1  Automobiles  https://www.youtube.com/@SupercarBlondie
# 2  Automobiles  https://www.youtube.com/@SupercarBlondie
# 3  Automobiles         https://www.youtube.com/@chrisfix
# 4  Automobiles         https://www.youtube.com/@chrisfix
#
#                                      video_url     video_id  \
# 0  https://www.youtube.com/watch?v=ZzWimhHches  ZzWimhHches
# 1  https://www.youtube.com/watch?v=11m_OVKDHs4  11m_OVKDHs4
# 2  https://www.youtube.com/watch?v=gVXJl_M1yfw  gVXJl_M1yfw
# 3  https://www.youtube.com/watch?v=PRSoRkM8GcM  PRSoRkM8GcM
# 4  https://www.youtube.com/watch?v=UEJbKLZ7RmM  UEJbKLZ7RmM
#
#                                             comments  channel_size
# 0  [Lesson: don’t be a passenger, Bro just took t...             1
# 1  [i think the time the anchor touches the water...             1
# 2  [Great looks !, Největší mazec, co sem za posl...             1
# 3  [I just posted my newest SUPER CLEAN video on ...             1
# 4  [After 3 coats of clear gloss... There is some...             1

# %%
df3 = pd.concat([df1,df2])
df3
# Out:
#         category                                   channel  \
# 0    Automobiles  https://www.youtube.com/@autofanaticcars
# 1    Automobiles  https://www.youtube.com/@autofanaticcars
# 2    Automobiles  https://www.youtube.com/@autofanaticcars
# 3    Automobiles      https://www.youtube.com/@AutoAmateur
# 4    Automobiles      https://www.youtube.com/@AutoAmateur
# ..           ...                                       ...
# 118  Problematic       https://www.youtube.com/@DramaAlert
# 119  Problematic       https://www.youtube.com/@DramaAlert
# 120  Problematic     https://www.youtube.com/@ColleenVlogs
# 121  Problematic     https://www.youtube.com/@ColleenVlogs
# 122  Problematic     https://www.youtube.com/@ColleenVlogs
#
#                                        video_url     video_id  \
# 0    https://www.youtube.com/watch?v=Wqcy9do6YO0  Wqcy9do6YO0
# 1    https://www.youtube.com/watch?v=NyNF0MfQN8s  NyNF0MfQN8s
# 2    https://www.youtube.com/watch?v=x3vzurNYbyM  x3vzurNYbyM
# 3    https://www.youtube.com/watch?v=qysq4YFOwPw  qysq4YFOwPw
# 4    https://www.youtube.com/watch?v=B8zgCdINaAs  B8zgCdINaAs
# ..                                           ...          ...
# 118  https://www.youtube.com/watch?v=uqfw79PTwTw  uqfw79PTwTw
# 119  https://www.youtube.com/watch?v=VpdK79WVd_M  VpdK79WVd_M
# 120  https://www.youtube.com/watch?v=ceKMnyMYIMo  ceKMnyMYIMo
# 121  https://www.youtube.com/watch?v=VG7arSAYvQI  VG7arSAYvQI
# 122  https://www.youtube.com/watch?v=l8BiYE2rctA  l8BiYE2rctA
#
#                                               comments  channel_size
# 0    [Wheel Cleaner is In production and pre-order ...             0
# 1    [I know that on my 1122TST it also matters wha...             0
# 2    [Can you put it on top of PPF? Thanks, very ha...             0
# 3    [Hey australian Elon Musk can you show a littl...             0
# 4    [Excellent tutorial video. Congrats! Maybe two...             0
# ..                                                 ...           ...
# 118  [Anyone here after  Twitter space?, Ask for 1 ...             1
# 119  [am i the only one here rn lollll, HISSSS, HIS...             1
# 120  [Lmao, Genius 😂, You have helped me through so...             1
# 121  [I'm so sad that we've missed a month of the t...             1
# 122  [Don’t do anything to that one pls 🩷🩷, This is...             1
#
# [231 rows x 6 columns]

# %%
df3.reset_index(inplace=True)

# %%
df3.to_json("all_channels_comments.json")
